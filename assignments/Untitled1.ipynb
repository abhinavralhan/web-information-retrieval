# %%
import numpy as np

game_of_throne_prediction = [4]
stranger_things_prediction = [4]
black_mirror_prediction = [5, 4, 4]
black_list_prediction = [3]
the_boys_prediction = [5, 3, 5]

game_of_throne_actual = [1]
stranger_things_actual = [4]
black_mirror_actual= [3, 1, 4]
black_list_actual = [2]
the_boys_actual = [5, 3, 4]

predictions = game_of_throne_prediction + stranger_things_prediction + black_mirror_prediction + black_list_prediction + the_boys_prediction
actuals = game_of_throne_actual + stranger_things_actual + black_mirror_actual + black_list_actual + the_boys_actual

rmse = np.sqrt(np.mean((np.array(predictions) - np.array(actuals))**2))
rmse
# Out:
# 1.632993161855452
